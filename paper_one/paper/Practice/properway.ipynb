# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanicData = pd.read_csv("/home/thinkpad/Documents/BrototypeStudying/paper_one/paper/tempData/Titanic-Dataset.csv")

# %%
Data = titanicData.copy()
Data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
nullValues = Data.isnull().sum()
print(nullValues)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
pd.crosstab(Data["Sex"], Data["Survived"], normalize="index")
# Out:
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
pd.crosstab(Data["Pclass"], Data["Survived"], normalize="index")
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %%
plt.hist(Data["Age"].dropna(),edgecolor = "black", bins=10)
plt.xlabel("Age")
plt.ylabel("Passenger")
plt.show()

# %%
Data.boxplot(column="Age", by="Survived")
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Survived'>

# %%
print(Data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Data["Age"] = Data["Age"].fillna(Data["Age"].median())
# print(Data.isnull().sum())

# %%
Data["Embarked"] = Data["Embarked"].fillna(Data["Embarked"].mode()[0])
Data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
Data["Sex"] = Data["Sex"].map({
    "male" : 0,
    "female" : 1
})

# %%
pd.get_dummies(Data["Embarked"], drop_first=True)
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 2 columns]
