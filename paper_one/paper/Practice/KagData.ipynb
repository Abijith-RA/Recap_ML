# %%
import pandas as pd

details = pd.read_csv("/home/thinkpad/Documents/BrototypeStudying/paper_one/paper/tempData/Titanic-Dataset.csv")

data = details.copy()

print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None

# %%
print(data.isnull().sum())
print("Median Age -", data["Age"].median())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Median Age - 28.0

# %%
# data["Age"] = data["Age"].fillna(data["Age"].median())
data.isnull().sum()

# pd.options.display.max_rows = 891
# print(data)

correlation = data.corr(numeric_only = "True")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(correlation, annot = True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
# sns.pairplot(data, vars=['Age', 'Fare', 'Pclass', 'SibSp', 'Parch'], hue='Survived')
sns.barplot(x='Pclass', y='Survived', data=data)
plt.show()

# %%
print(data["Survived"].value_counts())
# Out:
# Survived
# 0    424
# 1    290
# Name: count, dtype: int64

# %%
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              7         0       1
# 6              8         0       3
# 7              9         1       3
# 8             10         1       2
# 9             11         1       3
# 10            12         1       1
# 11            13         0       3
# 12            14         0       3
# 13            15         0       3
# 14            16         1       2
# 15            17         0       3
# 16            19         0       3
# 17            21         0       2
# 18            22         1       2
# 19            23         1       3
# 20            24         1       1
# 21            25         0       3
# 22            26         1       3
# 23            28         0       1
# 24            31         0       1
# ...

# %%
data["Age"].isnull().sum()
# Out:
# np.int64(177)

# %%
data = data.dropna(subset="Age")
data = data.reset_index(drop="True")
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              7         0       1
# 6              8         0       3
# 7              9         1       3
# 8             10         1       2
# 9             11         1       3
# 10            12         1       1
# 11            13         0       3
# 12            14         0       3
# 13            15         0       3
# 14            16         1       2
# 15            17         0       3
# 16            19         0       3
# 17            21         0       2
# 18            22         1       2
# 19            23         1       3
# 20            24         1       1
# 21            25         0       3
# 22            26         1       3
# 23            28         0       1
# 24            31         0       1
# ...

# %%
print(data.shape)
# Out:
# (714, 12)

# %%
plt.scatter(data["Survived"], data["Age"])
plt.show()

# %%
sns.boxplot(data=data, x="Survived", y="Age")
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
pd.crosstab(data["Sex"], data["Survived"], normalize="index")
# Out:
# Survived         0         1
# Sex
# female    0.245211  0.754789
# male      0.794702  0.205298

# %%
pd.crosstab(data["Pclass"], data["Survived"], normalize="index")
# Out:
# Survived         0         1
# Pclass
# 1         0.344086  0.655914
# 2         0.520231  0.479769
# 3         0.760563  0.239437

# %%
plt.hist(data["Age"].dropna(),bins=10,edgecolor="black")
plt.xlabel("Age")
plt.ylabel("passenger")
# Out:
# Text(0, 0.5, 'passenger')

# %%
print(data[(data["Age"] > 70) & (data["Survived"] == 1)] ["Name"])
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: str
