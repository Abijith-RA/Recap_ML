# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

data = {
    "Student_ID": range(1, 31),

    "Gender": [
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female"
    ],

    "Age": [
        20, 21, 19, 22, 20, 19, 21, 20, 22, 21,
        19, 20, 21, 22, 20, 19, 22, 21, 20, 22,
        19, 20, 21, 19, 22, 21, 20, 22, 19, 20
    ],

    "Study_Hours": [
        2.5, 4.0, 1.5, 5.0, 3.0, 2.0, 4.5, 3.5, 1.0, 5.5,
        2.5, 4.0, 3.0, 2.0, 5.0, 3.5, 1.5, 4.5, 2.0, 5.0,
        3.0, 4.0, 1.5, 3.5, 4.5, 2.5, 1.0, 5.5, 3.5, 4.5
    ],

    "Attendance": [
        72, 85, 65, 92, 78, 70, 88, 82, 60, 95,
        74, 87, 79, 68, 91, 80, 63, 89, 71, 94,
        77, 86, 66, 83, 90, 75, 62, 96, 81, 88
    ],

    "Previous_Score": [
        58, 72, 49, 81, 65, 55, 76, 68, 45, 88,
        60, 75, 62, 52, 84, 70, 47, 79, 56, 86,
        64, 73, 51, 69, 78, 59, 44, 90, 67, 77
    ],

    "Assignment_Score": [
        62, 78, 55, 88, 70, 60, 82, 75, 50, 92,
        65, 80, 68, 58, 86, 72, 53, 84, 61, 90,
        69, 79, 54, 76, 83, 64, 49, 94, 71, 85
    ],

    "Final_Score": [
        61, 79, 52, 87, 68, 57, 80, 73, 48, 91,
        63, 78, 66, 55, 88, 71, 50, 82, 59, 89,
        67, 77, 53, 74, 81, 62, 46, 93, 69, 83
    ],

    "Internet_Access": [
        "Yes", "Yes", "No", "Yes", "Yes",
        "No", "Yes", "Yes", "No", "Yes",
        "Yes", "Yes", "No", "No", "Yes",
        "Yes", "No", "Yes", "Yes", "Yes",
        "No", "Yes", "No", "Yes", "Yes",
        "No", "No", "Yes", "Yes", "Yes"
    ],

    "Passed": [
        "No", "Yes", "No", "Yes", "Yes",
        "No", "Yes", "Yes", "No", "Yes",
        "Yes", "Yes", "Yes", "No", "Yes",
        "Yes", "No", "Yes", "No", "Yes",
        "Yes", "Yes", "No", "Yes", "Yes",
        "Yes", "No", "Yes", "Yes", "Yes"
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the data
print(df)

# Save as CSV
df.to_csv("student_performance.csv", index=False)

print("CSV file created successfully!")
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Previous_Score  \
# 0            1    Male   20          2.5          72              58
# 1            2  Female   21          4.0          85              72
# 2            3    Male   19          1.5          65              49
# 3            4  Female   22          5.0          92              81
# 4            5    Male   20          3.0          78              65
# 5            6  Female   19          2.0          70              55
# 6            7    Male   21          4.5          88              76
# 7            8  Female   20          3.5          82              68
# 8            9    Male   22          1.0          60              45
# 9           10  Female   21          5.5          95              88
# 10          11    Male   19          2.5          74              60
# 11          12  Female   20          4.0          87              75
# 12          13    Male   21          3.0          79              62
# ...

# %% [markdown]
# Analyze the relationship between Study_Hours and Final_Score.
#     * Create an appropriate visualization.
#     * Calculate correlation.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student_ID        30 non-null     int64
#  1   Gender            30 non-null     str
#  2   Age               30 non-null     int64
#  3   Study_Hours       30 non-null     float64
#  4   Attendance        30 non-null     int64
#  5   Previous_Score    30 non-null     int64
#  6   Assignment_Score  30 non-null     int64
#  7   Final_Score       30 non-null     int64
#  8   Internet_Access   30 non-null     str
#  9   Passed            30 non-null     str
# dtypes: float64(1), int64(6), str(3)
# memory usage: 2.5 KB

# %%
df.head(5)
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Previous_Score  \
# 0           1    Male   20          2.5          72              58
# 1           2  Female   21          4.0          85              72
# 2           3    Male   19          1.5          65              49
# 3           4  Female   22          5.0          92              81
# 4           5    Male   20          3.0          78              65
#
#    Assignment_Score  Final_Score Internet_Access Passed
# 0                62           61             Yes     No
# 1                78           79             Yes    Yes
# 2                55           52              No     No
# 3                88           87             Yes    Yes
# 4                70           68             Yes    Yes

# %%
df["Study_Hours"].astype(int)
# Out:
# 0     2
# 1     4
# 2     1
# 3     5
# 4     3
# 5     2
# 6     4
# 7     3
# 8     1
# 9     5
# 10    2
# 11    4
# 12    3
# 13    2
# 14    5
# 15    3
# 16    1
# 17    4
# 18    2
# 19    5
# 20    3
# 21    4
# 22    1
# 23    3
# 24    4
# 25    2
# 26    1
# 27    5
# 28    3
# 29    4
# Name: Study_Hours, dtype: int64

# %%
df["Final_Score"].corr(df["Study_Hours"])
# Out:
# np.float64(0.9953522278828414)

# %%
df.corr?
# Out:
# Signature:
# df.corr(
#     method: 'CorrelationMethod' = 'pearson',
#     min_periods: 'int' = 1,
#     numeric_only: 'bool' = False,
# ) -> 'DataFrame'
# Docstring:
# Compute pairwise correlation of columns, excluding NA/null values.
#
# Parameters
# ----------
# method : {'pearson', 'kendall', 'spearman'} or callable
#     Method of correlation:
#
#     * pearson : standard correlation coefficient
#     * kendall : Kendall Tau correlation coefficient
#     * spearman : Spearman rank correlation
#     * callable: callable with input two 1d ndarrays
#         and returning a float. Note that the returned matrix from corr
#         will have 1 along the diagonals and will be symmetric
#         regardless of the callable's behavior.
# min_periods : int, optional
#     Minimum number of observations required per pair of columns
#     to have a valid result. Currently only available for Pearson
#     and Spearman correlation.
# numeric_only : bool, default False
# ...
