# %%
import pandas as pd
df = pd.read_csv("/home/thinkpad/Documents/BrototypeStudying/Paper two/week 9/data/loan_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   applicant_id      605 non-null    str
#  1   age               605 non-null    int64
#  2   income            589 non-null    float64
#  3   employment_type   605 non-null    str
#  4   credit_history    595 non-null    float64
#  5   loan_amount       605 non-null    float64
#  6   application_date  605 non-null    str
#  7   default           605 non-null    int64
# dtypes: float64(3), int64(2), str(3)
# memory usage: 37.9 KB

# %%
df[["income","loan_amount"]].describe().round(2)
# Out:
#           income  loan_amount
# count     589.00       605.00
# mean    37562.81    173145.62
# std     48978.92    225805.21
# min       188.49     20000.00
# 25%     18780.00     70578.00
# 50%     29014.00    132893.00
# 75%     44996.00    209482.00
# max    976668.00   4068981.00

# %%
df["income"].skew().round(2)
#right Skewed
# Out:
# np.float64(13.06)

# %%
df["age"].describe()
# Out:
# count    605.000000
# mean      38.628099
# std        9.596954
# min       21.000000
# 25%       32.000000
# 50%       38.000000
# 75%       45.000000
# max       65.000000
# Name: age, dtype: float64

# %%
df["age"].mode()[0]
# Out:
# np.int64(40)

# %%
unique = df[["income", "loan_amount"]].nunique()
print(unique)
# colum = unique.idxmax()
# print(colum)
# Out:
# income         582
# loan_amount    564
# dtype: int64

# %%
Q1 = df["income"].quantile(0.25)
Q3 = df["income"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["income"] < lower_bound) | (df["income"] > upper_bound)]
print(outliers)
# Out:
#     applicant_id  age    income employment_type  credit_history  loan_amount  \
# 1        APP1200   64   87125.0   Self-employed             1.0     362944.0
# 6        APP1222   27  106471.0        Salaried             1.0     492884.0
# 16       APP1359   40   97807.0        Salaried             1.0     586814.0
# 42       APP1070   30  106656.0   Self-employed             1.0     606720.0
# 46       APP1328   42   97394.0        Salaried             1.0     409367.0
# 50       APP1543   44  103034.0   Self-employed             1.0     556471.0
# 92       APP1493   31  421212.0        Salaried             1.0    2421720.0
# 105      APP1179   34  122865.0        Salaried             1.0     576625.0
# 117      APP1571   42   85856.0   Self-employed             0.0     396980.0
# 133      APP1595   52  123533.0        Salaried             0.0     345976.0
# 209      APP1220   24   86141.0   Self-employed             1.0     386814.0
# ...

# %%
df["age"].describe()
# Out:
# count    605.000000
# mean      38.628099
# std        9.596954
# min       21.000000
# 25%       32.000000
# 50%       38.000000
# 75%       45.000000
# max       65.000000
# Name: age, dtype: float64

# %%
df["age"].mode()[0]
# Out:
# 0    40
# Name: age, dtype: int64

# %%
summary = pd.DataFrame({
    "Data Type" : df.dtypes,
    "Missing" : df.isnull().sum(),
    "Unique Count" : df.nunique()
})
print(summary)
# Out:
#                  Data Type  Missing  Unique Count
# applicant_id           str        0           600
# age                  int64        0            45
# income             float64       16           582
# employment_type        str        0             3
# credit_history     float64       10             2
# loan_amount        float64        0           564
# application_date       str        0           363
# default              int64        0             2

# %%
cv_income = df['income'].std() / df['income'].mean()
cv_loan = df['loan_amount'].std() / df['loan_amount'].mean()
print(cv_income, cv_loan)
# Out:
# 1.3039207554962997 1.3041346713017936

# %%
df["income"].std()
# Out:
# np.float64(48978.924512949045)

# %%
df["income"].quantile(0.99)
# Out:
# np.float64(130077.28000000009)

# %%
category_col = df.select_dtypes(include=["category"]).columns
print(category_col)
# Out:
# Index([], dtype='str')
