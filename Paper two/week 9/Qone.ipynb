# %%
import pandas as pd
df = pd.read_csv("/home/thinkpad/Documents/BrototypeStudying/Paper two/week 9/data/loan_data.csv")

# %%
print("Shape", df.shape,"\n")
print(df.info(),"\n")
# Out:
# Shape (605, 8)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   applicant_id      605 non-null    str
#  1   age               605 non-null    int64
#  2   income            589 non-null    float64
#  3   employment_type   605 non-null    str
#  4   credit_history    595 non-null    float64
#  5   loan_amount       605 non-null    float64
#  6   application_date  605 non-null    str
#  7   default           605 non-null    int64
# dtypes: float64(3), int64(2), str(3)
# memory usage: 37.9 KB
# None

# %%
print(df['income'].skew())
# Out:
# 13.05556008978119

# %%
df.describe().round(2)
# Out:
#           age     income  credit_history  loan_amount  default
# count  605.00     589.00          595.00       605.00   605.00
# mean    38.63   37562.81            0.86    173145.62     0.29
# std      9.60   48978.92            0.35    225805.21     0.46
# min     21.00     188.49            0.00     20000.00     0.00
# 25%     32.00   18780.00            1.00     70578.00     0.00
# 50%     38.00   29014.00            1.00    132893.00     0.00
# 75%     45.00   44996.00            1.00    209482.00     1.00
# max     65.00  976668.00            1.00   4068981.00     1.00

# %%
print(df["employment_type"].value_counts(), "\n\n")
print(df.groupby("employment_type")["income"].mean(), "\n\n")
print(df.groupby("employment_type")["default"].mean())
# Out:
# employment_type
# Salaried         352
# Self-employed    184
# Unemployed        69
# Name: count, dtype: int64
#
#
# employment_type
# Salaried         37181.758660
# Self-employed    49036.336990
# Unemployed        8506.522388
# Name: income, dtype: float64
#
#
# employment_type
# Salaried         0.181818
# Self-employed    0.331522
# Unemployed       0.753623
# Name: default, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(df["income"].dropna())
plt.ticklabel_format(style="plain", axis="y")

# %% [markdown]
# Here the Dataset Have 605 row of data With on that there the 8 colum have or features
# age, income, credit_history, loan_amount, default are the numerical column
# The other two column that string
# Also have outlier and anomalies
