# %%
import pandas as pd

data = [
    {
        "id": 1,
        "name": "Samantha Johnson",
        "age": 21,
        "salary": 59387.02,
        "email": "samantha.johnson@example.com",
        "phone": "+1-892-858-9935",
        "city": None,
        "department": "Operations",
        "join_date": "2015-01-03"
    },
    {
        "id": 2,
        "name": "Sandra Anderson",
        "age": 58,
        "salary": 97349.41,
        "email": "sandra.anderson@example.com",
        "phone": "+1-425-559-5557",
        "city": "Houston",
        "department": "Operations",
        "join_date": "2020-05-05"
    },
    {
        "id": 3,
        "name": "Ruth Wilson",
        "age": 26,
        "salary": 75591.28,
        "email": "ruth.wilson@example.com",
        "phone": "+1-818-370-1711",
        "city": "Miami",
        "department": "Engineering",
        "join_date": "2021-02-18"
    },
    {
        "id": 4,
        "name": "Benjamin Thomas",
        "age": None,
        "salary": 53074.63,
        "email": "benjamin.thomas@example.com",
        "phone": "+1-877-333-5741",
        "city": "Phoenix",
        "department": "Engineering",
        "join_date": "2021-05-15"
    },
    {
        "id": 5,
        "name": "Christopher Wilson",
        "age": 42,
        "salary": 110421.02,
        "email": None,
        "phone": "+1-850-275-9751",
        "city": "Houston",
        "department": "IT",
        "join_date": "2021-05-21"
    },
    {
        "id": 6,
        "name": "Mark Wilson",
        "age": 23,
        "salary": 128616.31,
        "email": "mark.wilson@example.com",
        "phone": None,
        "city": "Seattle",
        "department": "HR",
        "join_date": "2022-07-21"
    },
    {
        "id": 7,
        "name": "Charles Miller",
        "age": 28,
        "salary": 119398.68,
        "email": "charles.miller@example.com",
        "phone": None,
        "city": "Boston",
        "department": "Support",
        "join_date": "2018-03-17"
    },
    {
        "id": 8,
        "name": "Barbara Smith",
        "age": 27,
        "salary": 105293.53,
        "email": None,
        "phone": None,
        "city": "Denver",
        "department": None,
        "join_date": "2019-09-28"
    },
    {
        "id": 9,
        "name": "Debra Johnson",
        "age": 63,
        "salary": 120105.34,
        "email": "debra.johnson@example.com",
        "phone": "+1-500-545-3591",
        "city": "New York",
        "department": "Finance",
        "join_date": "2023-03-17"
    },
    {
        "id": 10,
        "name": "Benjamin Miller",
        "age": 60,
        "salary": 103076.43,
        "email": "benjamin.miller@example.com",
        "phone": "+1-980-265-9837",
        "city": "New York",
        "department": "Support",
        "join_date": "2022-01-04"
    },
    {
        "id": 11,
        "name": "Michelle Davis",
        "age": 23,
        "salary": 135361.15,
        "email": "michelle.davis@example.com",
        "phone": "+1-949-597-2133",
        "city": "Houston",
        "department": "Marketing",
        "join_date": "2022-09-06"
    },
    {
        "id": 12,
        "name": "Angela Thomas",
        "age": 47,
        "salary": 141469.62,
        "email": "angela.thomas@example.com",
        "phone": "+1-608-787-7118",
        "city": "Miami",
        "department": "IT",
        "join_date": "2016-04-08"
    },
    {
        "id": 13,
        "name": "Carol Smith",
        "age": 57,
        "salary": 57613.77,
        "email": "carol.smith@example.com",
        "phone": "+1-272-824-1964",
        "city": "Chicago",
        "department": "Sales",
        "join_date": "2020-02-17"
    },
    {
        "id": 14,
        "name": "Emily Taylor",
        "age": 33,
        "salary": None,
        "email": None,
        "phone": "+1-684-348-8749",
        "city": "Phoenix",
        "department": "Engineering",
        "join_date": "2016-11-14"
    },
    {
        "id": 15,
        "name": "Jason Moore",
        "age": 49,
        "salary": 110803.75,
        "email": "jason.moore@example.com",
        "phone": "+1-612-845-6559",
        "city": "Phoenix",
        "department": "HR",
        "join_date": "2018-09-15"
    },
    {
        "id": 16,
        "name": "Jason Brown",
        "age": 37,
        "salary": 59976.77,
        "email": "jason.brown@example.com",
        "phone": "+1-763-200-1828",
        "city": "New York",
        "department": "Engineering",
        "join_date": "2018-03-14"
    },
    {
        "id": 17,
        "name": "Kathleen Davis",
        "age": 45,
        "salary": 49756.45,
        "email": "kathleen.davis@example.com",
        "phone": "+1-471-902-8454",
        "city": "Boston",
        "department": None,
        "join_date": "2022-03-07"
    },
    {
        "id": 18,
        "name": "Margaret Smith",
        "age": 57,
        "salary": 37314.91,
        "email": "margaret.smith@example.com",
        "phone": "+1-251-698-8811",
        "city": "Miami",
        "department": "Marketing",
        "join_date": "2015-09-03"
    },
    {
        "id": 19,
        "name": "William Thomas",
        "age": 24,
        "salary": None,
        "email": "william.thomas@example.com",
        "phone": None,
        "city": "Chicago",
        "department": "Operations",
        "join_date": "2024-10-17"
    },
    {
        "id": 20,
        "name": "Kimberly Davis",
        "age": 62,
        "salary": 58642.31,
        "email": "kimberly.davis@example.com",
        "phone": "+1-887-760-5915",
        "city": "Seattle",
        "department": "Engineering",
        "join_date": None
    },
    {
        "id": 21,
        "name": "Richard Johnson",
        "age": 54,
        "salary": 90706.16,
        "email": "richard.johnson@example.com",
        "phone": "+1-270-350-7054",
        "city": "Houston",
        "department": "IT",
        "join_date": None
    },
    {
        "id": 22,
        "name": "Katherine Anderson",
        "age": 20,
        "salary": 65925.45,
        "email": "katherine.anderson@example.com",
        "phone": "+1-470-218-2753",
        "city": "Houston",
        "department": "Finance",
        "join_date": "2019-10-07"
    },
    {
        "id": 23,
        "name": "Anthony Miller",
        "age": 52,
        "salary": 60134.55,
        "email": "anthony.miller@example.com",
        "phone": "+1-849-533-5533",
        "city": "New York",
        "department": "Support",
        "join_date": "2017-11-09"
    },
    {
        "id": 24,
        "name": "Jack Taylor",
        "age": 55,
        "salary": 97308.82,
        "email": "jack.taylor@example.com",
        "phone": "+1-907-252-9938",
        "city": "Seattle",
        "department": None,
        "join_date": "2017-07-05"
    },
    {
        "id": 25,
        "name": "Michelle Wilson",
        "age": 22,
        "salary": 55209.18,
        "email": "michelle.wilson@example.com",
        "phone": None,
        "city": "Houston",
        "department": "HR",
        "join_date": "2017-03-14"
    },
    {
        "id": 26,
        "name": "Daniel Wilson",
        "age": 46,
        "salary": 62016.69,
        "email": "daniel.wilson@example.com",
        "phone": "+1-239-979-8711",
        "city": "Phoenix",
        "department": "IT",
        "join_date": "2020-05-27"
    },
    {
        "id": 27,
        "name": "Mark Smith",
        "age": 62,
        "salary": 77815.92,
        "email": "mark.smith@example.com",
        "phone": "+1-991-385-6753",
        "city": "Boston",
        "department": None,
        "join_date": "2020-01-04"
    },
    {
        "id": 28,
        "name": "Daniel Thomas",
        "age": 36,
        "salary": 43008.31,
        "email": "daniel.thomas@example.com",
        "phone": "+1-946-905-6139",
        "city": None,
        "department": None,
        "join_date": "2016-07-19"
    },
    {
        "id": 29,
        "name": "Steven Smith",
        "age": 65,
        "salary": 30202.95,
        "email": "steven.smith@example.com",
        "phone": "+1-572-541-2146",
        "city": None,
        "department": "Support",
        "join_date": "2016-12-10"
    },
    {
        "id": 30,
        "name": "Michelle Moore",
        "age": 40,
        "salary": 113665.01,
        "email": "michelle.moore@example.com",
        "phone": "+1-396-530-7211",
        "city": None,
        "department": "Finance",
        "join_date": "2021-09-27"
    },
    {
        "id": 31,
        "name": "Joshua Miller",
        "age": 33,
        "salary": None,
        "email": "joshua.miller@example.com",
        "phone": "+1-676-552-8244",
        "city": "Miami",
        "department": "IT",
        "join_date": "2017-11-03"
    },
    {
        "id": 32,
        "name": "Shirley Thomas",
        "age": 41,
        "salary": 128210.82,
        "email": "shirley.thomas@example.com",
        "phone": "+1-430-925-4262",
        "city": "New York",
        "department": "Sales",
        "join_date": "2018-08-20"
    },
    {
        "id": 33,
        "name": "Ryan Moore",
        "age": None,
        "salary": 53332.23,
        "email": "ryan.moore@example.com",
        "phone": "+1-609-349-3417",
        "city": "Chicago",
        "department": "Operations",
        "join_date": "2018-03-26"
    },
    {
        "id": 34,
        "name": "Cynthia Smith",
        "age": 55,
        "salary": 140096.4,
        "email": "cynthia.smith@example.com",
        "phone": "+1-336-920-8612",
        "city": "Miami",
        "department": "Support",
        "join_date": "2022-10-27"
    },
    {
        "id": 35,
        "name": "Jason Anderson",
        "age": 48,
        "salary": 119238.65,
        "email": "jason.anderson@example.com",
        "phone": "+1-465-869-5050",
        "city": "Miami",
        "department": "IT",
        "join_date": "2018-05-15"
    },
    {
        "id": 36,
        "name": "Catherine Miller",
        "age": 35,
        "salary": 70301.7,
        "email": "catherine.miller@example.com",
        "phone": "+1-341-254-4788",
        "city": "Houston",
        "department": "HR",
        "join_date": "2016-07-14"
    },
    {
        "id": 37,
        "name": "Helen Taylor",
        "age": 46,
        "salary": 54820.13,
        "email": "helen.taylor@example.com",
        "phone": None,
        "city": "Boston",
        "department": "IT",
        "join_date": "2015-06-10"
    },
    {
        "id": 38,
        "name": "Rebecca Anderson",
        "age": None,
        "salary": 137737.36,
        "email": "rebecca.anderson@example.com",
        "phone": "+1-479-546-8956",
        "city": "Boston",
        "department": "Support",
        "join_date": "2021-12-06"
    },
    {
        "id": 39,
        "name": "Thomas Thomas",
        "age": 54,
        "salary": None,
        "email": None,
        "phone": "+1-878-127-2375",
        "city": "Houston",
        "department": "IT",
        "join_date": "2017-01-09"
    },
    {
        "id": 40,
        "name": "Dorothy Davis",
        "age": 49,
        "salary": 70500.07,
        "email": "dorothy.davis@example.com",
        "phone": "+1-970-951-7906",
        "city": "Chicago",
        "department": "IT",
        "join_date": "2015-12-18"
    },
    {
        "id": 41,
        "name": "Brian Davis",
        "age": 61,
        "salary": 123747.97,
        "email": "brian.davis@example.com",
        "phone": None,
        "city": "Houston",
        "department": "HR",
        "join_date": "2017-08-22"
    },
    {
        "id": 42,
        "name": "Larry Davis",
        "age": 49,
        "salary": 122027.77,
        "email": None,
        "phone": "+1-821-865-2876",
        "city": "Austin",
        "department": "Engineering",
        "join_date": None
    },
    {
        "id": 43,
        "name": "Alexander Moore",
        "age": 45,
        "salary": 39119.58,
        "email": "alexander.moore@example.com",
        "phone": None,
        "city": "Chicago",
        "department": "Sales",
        "join_date": "2020-09-14"
    },
    {
        "id": 44,
        "name": "William Anderson",
        "age": 61,
        "salary": 31518.26,
        "email": "william.anderson@example.com",
        "phone": "+1-308-543-6934",
        "city": "Houston",
        "department": "Operations",
        "join_date": "2017-12-17"
    },
    {
        "id": 45,
        "name": "Brandon Anderson",
        "age": 50,
        "salary": None,
        "email": "brandon.anderson@example.com",
        "phone": "+1-530-972-5022",
        "city": "Austin",
        "department": "IT",
        "join_date": None
    },
    {
        "id": 46,
        "name": "Christine Moore",
        "age": 41,
        "salary": 89316.78,
        "email": "christine.moore@example.com",
        "phone": "+1-699-317-6813",
        "city": "Seattle",
        "department": "Finance",
        "join_date": "2024-12-09"
    },
    {
        "id": 47,
        "name": "Mary Anderson",
        "age": 32,
        "salary": 58962.73,
        "email": "mary.anderson@example.com",
        "phone": "+1-768-876-4937",
        "city": "Denver",
        "department": "IT",
        "join_date": "2015-02-10"
    },
    {
        "id": 48,
        "name": "Stephanie Davis",
        "age": None,
        "salary": 74282.45,
        "email": "stephanie.davis@example.com",
        "phone": "+1-552-535-6419",
        "city": "Denver",
        "department": "Finance",
        "join_date": "2019-05-08"
    },
    {
        "id": 49,
        "name": "Raymond Davis",
        "age": 40,
        "salary": 119145.73,
        "email": "raymond.davis@example.com",
        "phone": "+1-421-856-8933",
        "city": None,
        "department": None,
        "join_date": "2024-05-04"
    },
    {
        "id": 50,
        "name": "Donna Davis",
        "age": 43,
        "salary": 66272.11,
        "email": "donna.davis@example.com",
        "phone": "+1-480-146-1893",
        "city": "Austin",
        "department": "Marketing",
        "join_date": "2022-02-28"
    },
    {
        "id": 51,
        "name": "Brenda Miller",
        "age": 50,
        "salary": 82856.26,
        "email": "brenda.miller@example.com",
        "phone": "+1-458-982-8827",
        "city": "Chicago",
        "department": "Operations",
        "join_date": "2022-02-19"
    },
    {
        "id": 52,
        "name": "Karen Brown",
        "age": 56,
        "salary": 40221.71,
        "email": "karen.brown@example.com",
        "phone": None,
        "city": None,
        "department": "HR",
        "join_date": "2023-07-15"
    },
    {
        "id": 53,
        "name": "Joshua Thomas",
        "age": 47,
        "salary": 98235.54,
        "email": None,
        "phone": "+1-957-201-4404",
        "city": "Austin",
        "department": "Engineering",
        "join_date": "2017-04-06"
    },
    {
        "id": 54,
        "name": "Elizabeth Brown",
        "age": 20,
        "salary": None,
        "email": "elizabeth.brown@example.com",
        "phone": "+1-498-133-4792",
        "city": "Austin",
        "department": "IT",
        "join_date": "2016-11-08"
    },
    {
        "id": 55,
        "name": "Benjamin Thomas",
        "age": 62,
        "salary": 81016.68,
        "email": "benjamin.thomas@example.com",
        "phone": "+1-863-252-5352",
        "city": "Chicago",
        "department": "Sales",
        "join_date": None
    },
    {
        "id": 56,
        "name": "Andrew Taylor",
        "age": 27,
        "salary": 112641.36,
        "email": "andrew.taylor@example.com",
        "phone": "+1-712-652-9090",
        "city": "Chicago",
        "department": "Sales",
        "join_date": None
    },
    {
        "id": 57,
        "name": "Steven Smith",
        "age": 25,
        "salary": None,
        "email": None,
        "phone": None,
        "city": "New York",
        "department": "Marketing",
        "join_date": "2022-09-21"
    },
    {
        "id": 58,
        "name": "Emily Brown",
        "age": 57,
        "salary": 106174.17,
        "email": "emily.brown@example.com",
        "phone": "+1-681-456-7690",
        "city": "Seattle",
        "department": "Engineering",
        "join_date": "2017-06-14"
    },
    {
        "id": 59,
        "name": "Andrew Moore",
        "age": 55,
        "salary": 84579.11,
        "email": "andrew.moore@example.com",
        "phone": "+1-531-218-7622",
        "city": "New York",
        "department": None,
        "join_date": "2022-07-02"
    },
    {
        "id": 60,
        "name": "Eric Wilson",
        "age": 59,
        "salary": 105049.05,
        "email": "eric.wilson@example.com",
        "phone": "+1-473-662-3146",
        "city": "Denver",
        "department": "IT",
        "join_date": None
    },
    {
        "id": 61,
        "name": "Donald Brown",
        "age": 39,
        "salary": 31640.94,
        "email": "donald.brown@example.com",
        "phone": "+1-430-961-2858",
        "city": "Chicago",
        "department": "Marketing",
        "join_date": "2022-12-10"
    },
    {
        "id": 62,
        "name": "Frank Miller",
        "age": 46,
        "salary": 147629.36,
        "email": "frank.miller@example.com",
        "phone": "+1-764-248-7284",
        "city": None,
        "department": None,
        "join_date": "2017-02-09"
    },
    {
        "id": 63,
        "name": "Carol Anderson",
        "age": 37,
        "salary": 63940.68,
        "email": None,
        "phone": "+1-793-775-9022",
        "city": "Denver",
        "department": None,
        "join_date": "2022-06-11"
    },
    {
        "id": 64,
        "name": "Ruth Anderson",
        "age": 44,
        "salary": 141942.27,
        "email": "ruth.anderson@example.com",
        "phone": "+1-785-492-4826",
        "city": "New York",
        "department": "Support",
        "join_date": "2022-12-26"
    },
    {
        "id": 65,
        "name": "Deborah Brown",
        "age": 51,
        "salary": None,
        "email": "deborah.brown@example.com",
        "phone": "+1-302-995-8213",
        "city": "Miami",
        "department": "IT",
        "join_date": "2015-12-05"
    },
    {
        "id": 66,
        "name": "Katherine Brown",
        "age": 24,
        "salary": 123783.03,
        "email": "katherine.brown@example.com",
        "phone": "+1-838-809-7512",
        "city": "Seattle",
        "department": None,
        "join_date": "2021-06-21"
    },
    {
        "id": 67,
        "name": "Helen Smith",
        "age": 59,
        "salary": 58172.43,
        "email": "helen.smith@example.com",
        "phone": "+1-964-192-8110",
        "city": "Chicago",
        "department": "IT",
        "join_date": "2017-12-10"
    },
    {
        "id": 68,
        "name": "Jennifer Wilson",
        "age": 23,
        "salary": 73015.6,
        "email": "jennifer.wilson@example.com",
        "phone": None,
        "city": "Houston",
        "department": "Marketing",
        "join_date": "2017-02-20"
    },
    {
        "id": 69,
        "name": "Emma Davis",
        "age": None,
        "salary": 47174.13,
        "email": "emma.davis@example.com",
        "phone": "+1-670-361-1153",
        "city": "Austin",
        "department": None,
        "join_date": "2017-02-15"
    },
    {
        "id": 70,
        "name": "Pamela Miller",
        "age": 60,
        "salary": 112837.62,
        "email": "pamela.miller@example.com",
        "phone": "+1-403-493-8916",
        "city": "Phoenix",
        "department": "Operations",
        "join_date": "2024-06-19"
    },
    {
        "id": 71,
        "name": "Rachel Miller",
        "age": 21,
        "salary": None,
        "email": "rachel.miller@example.com",
        "phone": "+1-820-863-9138",
        "city": "Phoenix",
        "department": "Support",
        "join_date": None
    },
    {
        "id": 72,
        "name": "Steven Brown",
        "age": 60,
        "salary": 138408.44,
        "email": "steven.brown@example.com",
        "phone": "+1-651-134-6977",
        "city": "Chicago",
        "department": "Finance",
        "join_date": "2020-12-14"
    },
    {
        "id": 73,
        "name": "Betty Brown",
        "age": 54,
        "salary": 93702.28,
        "email": "betty.brown@example.com",
        "phone": "+1-463-944-8894",
        "city": "Seattle",
        "department": "Engineering",
        "join_date": "2022-02-05"
    },
    {
        "id": 74,
        "name": "Alexander Moore",
        "age": 55,
        "salary": 40836.35,
        "email": "alexander.moore@example.com",
        "phone": "+1-470-649-3024",
        "city": "Seattle",
        "department": "Finance",
        "join_date": "2024-07-27"
    },
    {
        "id": 75,
        "name": "Susan Davis",
        "age": 50,
        "salary": 104345.62,
        "email": "susan.davis@example.com",
        "phone": "+1-824-326-2035",
        "city": "Austin",
        "department": "Operations",
        "join_date": "2016-03-02"
    },
    {
        "id": 76,
        "name": "Joshua Taylor",
        "age": 27,
        "salary": 58176.0,
        "email": "joshua.taylor@example.com",
        "phone": "+1-597-564-7078",
        "city": "Boston",
        "department": "Marketing",
        "join_date": "2021-11-04"
    },
    {
        "id": 77,
        "name": "Brandon Moore",
        "age": 37,
        "salary": 112833.68,
        "email": "brandon.moore@example.com",
        "phone": "+1-655-341-6942",
        "city": "Seattle",
        "department": None,
        "join_date": "2020-01-13"
    },
    {
        "id": 78,
        "name": "Matthew Johnson",
        "age": 49,
        "salary": None,
        "email": "matthew.johnson@example.com",
        "phone": "+1-251-905-6464",
        "city": "Houston",
        "department": "HR",
        "join_date": None
    },
    {
        "id": 79,
        "name": "Margaret Davis",
        "age": 41,
        "salary": None,
        "email": "margaret.davis@example.com",
        "phone": "+1-483-979-3370",
        "city": "Miami",
        "department": "Finance",
        "join_date": "2017-02-22"
    },
    {
        "id": 80,
        "name": "Thomas Smith",
        "age": 42,
        "salary": 100662.35,
        "email": "thomas.smith@example.com",
        "phone": "+1-471-153-3076",
        "city": "Miami",
        "department": "Engineering",
        "join_date": "2016-08-15"
    },
    {
        "id": 81,
        "name": "Shirley Thomas",
        "age": 26,
        "salary": None,
        "email": "shirley.thomas@example.com",
        "phone": "+1-944-902-9543",
        "city": "Denver",
        "department": "Sales",
        "join_date": "2015-08-28"
    },
    {
        "id": 82,
        "name": "Jason Johnson",
        "age": 51,
        "salary": 38818.89,
        "email": "jason.johnson@example.com",
        "phone": "+1-822-251-2076",
        "city": "Austin",
        "department": None,
        "join_date": "2020-07-20"
    },
    {
        "id": 83,
        "name": "Donna Taylor",
        "age": None,
        "salary": 81623.92,
        "email": "donna.taylor@example.com",
        "phone": "+1-938-986-4522",
        "city": "Denver",
        "department": "HR",
        "join_date": "2021-06-27"
    },
    {
        "id": 84,
        "name": "Stephanie Moore",
        "age": 26,
        "salary": 81211.68,
        "email": "stephanie.moore@example.com",
        "phone": "+1-356-803-8770",
        "city": "Chicago",
        "department": "Engineering",
        "join_date": "2016-07-04"
    },
    {
        "id": 85,
        "name": "Thomas Anderson",
        "age": None,
        "salary": 144794.95,
        "email": "thomas.anderson@example.com",
        "phone": "+1-886-225-7730",
        "city": "Boston",
        "department": "Sales",
        "join_date": "2019-10-10"
    },
    {
        "id": 86,
        "name": "Susan Thomas",
        "age": 52,
        "salary": 48567.62,
        "email": "susan.thomas@example.com",
        "phone": "+1-310-458-7022",
        "city": "Austin",
        "department": "HR",
        "join_date": None
    },
    {
        "id": 87,
        "name": "Brandon Anderson",
        "age": None,
        "salary": 141490.11,
        "email": "brandon.anderson@example.com",
        "phone": "+1-384-379-6062",
        "city": "Seattle",
        "department": "Sales",
        "join_date": "2017-03-19"
    },
    {
        "id": 88,
        "name": "William Brown",
        "age": 60,
        "salary": 41010.92,
        "email": "william.brown@example.com",
        "phone": "+1-585-529-8432",
        "city": "Houston",
        "department": "Support",
        "join_date": None
    },
    {
        "id": 89,
        "name": "Scott Johnson",
        "age": 23,
        "salary": None,
        "email": "scott.johnson@example.com",
        "phone": "+1-890-183-5458",
        "city": "Boston",
        "department": "IT",
        "join_date": "2024-08-14"
    },
    {
        "id": 90,
        "name": "Margaret Anderson",
        "age": 27,
        "salary": 81589.64,
        "email": None,
        "phone": "+1-698-639-6053",
        "city": "Phoenix",
        "department": "Operations",
        "join_date": "2024-01-01"
    },
    {
        "id": 91,
        "name": "Joshua Davis",
        "age": 28,
        "salary": 64733.66,
        "email": "joshua.davis@example.com",
        "phone": "+1-709-864-8055",
        "city": "Houston",
        "department": "Operations",
        "join_date": "2023-12-08"
    },
    {
        "id": 92,
        "name": "Anna Wilson",
        "age": 24,
        "salary": 133411.72,
        "email": "anna.wilson@example.com",
        "phone": "+1-219-570-2275",
        "city": None,
        "department": "Operations",
        "join_date": "2024-07-23"
    },
    {
        "id": 93,
        "name": "Donna Johnson",
        "age": 45,
        "salary": 145943.96,
        "email": None,
        "phone": "+1-671-951-6928",
        "city": "Boston",
        "department": "Engineering",
        "join_date": "2018-07-19"
    },
    {
        "id": 94,
        "name": "Angela Johnson",
        "age": 45,
        "salary": 119496.58,
        "email": "angela.johnson@example.com",
        "phone": "+1-997-272-2251",
        "city": "Chicago",
        "department": None,
        "join_date": "2023-04-25"
    },
    {
        "id": 95,
        "name": "Brian Brown",
        "age": 35,
        "salary": 47573.31,
        "email": "brian.brown@example.com",
        "phone": "+1-816-256-2234",
        "city": "Denver",
        "department": "IT",
        "join_date": None
    },
    {
        "id": 96,
        "name": "Samuel Thomas",
        "age": 40,
        "salary": 48114.89,
        "email": "samuel.thomas@example.com",
        "phone": "+1-652-746-5961",
        "city": None,
        "department": "Sales",
        "join_date": "2020-09-03"
    },
    {
        "id": 97,
        "name": "Cynthia Taylor",
        "age": 22,
        "salary": 74248.51,
        "email": "cynthia.taylor@example.com",
        "phone": None,
        "city": None,
        "department": None,
        "join_date": "2021-08-19"
    },
    {
        "id": 98,
        "name": "Jack Smith",
        "age": None,
        "salary": 108220.49,
        "email": None,
        "phone": "+1-687-613-3471",
        "city": "Denver",
        "department": "Engineering",
        "join_date": "2020-12-03"
    },
    {
        "id": 99,
        "name": "Samuel Brown",
        "age": 22,
        "salary": 114914.6,
        "email": "samuel.brown@example.com",
        "phone": "+1-735-724-3600",
        "city": "Seattle",
        "department": "Finance",
        "join_date": "2021-07-25"
    },
    {
        "id": 100,
        "name": "Alexander Thomas",
        "age": 23,
        "salary": 37909.42,
        "email": "alexander.thomas@example.com",
        "phone": "+1-894-495-5655",
        "city": None,
        "department": "Marketing",
        "join_date": "2020-02-19"
    }
]

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   name        100 non-null    str
#  2   age         91 non-null     float64
#  3   salary      87 non-null     float64
#  4   email       89 non-null     str
#  5   phone       88 non-null     str
#  6   city        89 non-null     str
#  7   department  85 non-null     str
#  8   join_date   88 non-null     str
# dtypes: float64(2), int64(1), str(6)
# memory usage: 7.2 KB

# %%
df.head(10)
# Out:
#    id                name   age     salary                         email  \
# 0   1    Samantha Johnson  21.0   59387.02  samantha.johnson@example.com
# 1   2     Sandra Anderson  58.0   97349.41   sandra.anderson@example.com
# 2   3         Ruth Wilson  26.0   75591.28       ruth.wilson@example.com
# 3   4     Benjamin Thomas   NaN   53074.63   benjamin.thomas@example.com
# 4   5  Christopher Wilson  42.0  110421.02                           NaN
# 5   6         Mark Wilson  23.0  128616.31       mark.wilson@example.com
# 6   7      Charles Miller  28.0  119398.68    charles.miller@example.com
# 7   8       Barbara Smith  27.0  105293.53                           NaN
# 8   9       Debra Johnson  63.0  120105.34     debra.johnson@example.com
# 9  10     Benjamin Miller  60.0  103076.43   benjamin.miller@example.com
#
#              phone      city   department   join_date
# 0  +1-892-858-9935       NaN   Operations  2015-01-03
# 1  +1-425-559-5557   Houston   Operations  2020-05-05
# ...

# %%
df.sample(10)
# Out:
#     id             name   age     salary                        email  \
# 24  25  Michelle Wilson  22.0   55209.18  michelle.wilson@example.com
# 77  78  Matthew Johnson  49.0        NaN  matthew.johnson@example.com
# 32  33       Ryan Moore   NaN   53332.23       ryan.moore@example.com
# 53  54  Elizabeth Brown  20.0        NaN  elizabeth.brown@example.com
# 72  73      Betty Brown  54.0   93702.28      betty.brown@example.com
# 70  71    Rachel Miller  21.0        NaN    rachel.miller@example.com
# 76  77    Brandon Moore  37.0  112833.68    brandon.moore@example.com
# 27  28    Daniel Thomas  36.0   43008.31    daniel.thomas@example.com
# 17  18   Margaret Smith  57.0   37314.91   margaret.smith@example.com
# 96  97   Cynthia Taylor  22.0   74248.51   cynthia.taylor@example.com
#
#               phone     city   department   join_date
# 24              NaN  Houston           HR  2017-03-14
# 77  +1-251-905-6464  Houston           HR         NaN
# ...

# %%
pd.set_option('display.max_row',None)
pd.set_option('display.max_column',None)
df.index += 1
print(df.to_string())
# Out:
#       id                name   age     salary                           email            phone      city   department   join_date
# 1      1    Samantha Johnson  21.0   59387.02    samantha.johnson@example.com  +1-892-858-9935       NaN   Operations  2015-01-03
# 2      2     Sandra Anderson  58.0   97349.41     sandra.anderson@example.com  +1-425-559-5557   Houston   Operations  2020-05-05
# 3      3         Ruth Wilson  26.0   75591.28         ruth.wilson@example.com  +1-818-370-1711     Miami  Engineering  2021-02-18
# 4      4     Benjamin Thomas   NaN   53074.63     benjamin.thomas@example.com  +1-877-333-5741   Phoenix  Engineering  2021-05-15
# 5      5  Christopher Wilson  42.0  110421.02                             NaN  +1-850-275-9751   Houston           IT  2021-05-21
# 6      6         Mark Wilson  23.0  128616.31         mark.wilson@example.com              NaN   Seattle           HR  2022-07-21
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# age            9
# salary        13
# email         11
# phone         12
# city          11
# department    15
# join_date     12
# dtype: int64

# %%
df.describe()
# Out:
#                id        age         salary
# count  100.000000  91.000000      87.000000
# mean    50.500000  42.230769   86568.111379
# std     29.011492  13.577823   34301.813107
# min      1.000000  20.000000   30202.950000
# 25%     25.750000  27.500000   58174.215000
# 50%     50.500000  45.000000   81623.920000
# 75%     75.250000  54.000000  114289.805000
# max    100.000000  65.000000  147629.360000

# %%
# df["LPA"] = df["salary"] * 12
# df = df.drop(columns=["LPA"])

# %%
# df.info()
# df.isnull().sum()
print(df.shape, df.ndim, df.size)
# Out:
# (100, 9) 2 900

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'salary', 'email', 'phone', 'city', 'department',
#        'join_date'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# age            9
# salary        13
# email         11
# phone         12
# city          11
# department    15
# join_date     12
# dtype: int64

# %%
round(df["age"].mean())
# Out:
# 42

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   name        100 non-null    str
#  2   age         100 non-null    float64
#  3   salary      87 non-null     float64
#  4   email       89 non-null     str
#  5   phone       88 non-null     str
#  6   city        89 non-null     str
#  7   department  85 non-null     str
#  8   join_date   88 non-null     str
# dtypes: float64(2), int64(1), str(6)
# memory usage: 7.2 KB

# %%
Q1 = df["salary"].quantile(0.25)
Q3 = df["salary"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outlier = df[(df["salary"] < lower_bound) | (df["salary"] > upper_bound)]
print(outlier)
# Out:
# Empty DataFrame
# Columns: [id, name, age, salary, email, phone, city, department, join_date]
# Index: []

# %%
import matplotlib.pyplot as plt

df.boxplot(column="salary")
plt.show()

# %%
df.info()
# df["salary"] = df["salary"].fillna(df["salary"].mean())

# %%
df["city"].mode()[0]
df["city"] = df["city"].fillna(df["city"].mode()[0])

# %%
df["department"].mode()[0]
df["department"] = df["department"].fillna(df["department"].mode()[0])

# %%
df = df.drop(columns=["id", "name", "email", "phone", "join_date"])

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         100 non-null    float64
#  1   salary      87 non-null     float64
#  2   city        100 non-null    str
#  3   department  100 non-null    str
# dtypes: float64(2), str(2)
# memory usage: 3.3 KB
#               age         salary
# count  100.000000      87.000000
# mean    42.230769   86568.111379
# std     12.945946   34301.813107
# min     20.000000   30202.950000
# 25%     31.000000   58174.215000
# 50%     42.230769   81623.920000
# 75%     52.500000  114289.805000
# max     65.000000  147629.360000

# %%
df = pd.get_dummies(df, columns=["city", "department"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     100 non-null    float64
#  1   salary                  87 non-null     float64
#  2   city_Austin             100 non-null    bool
#  3   city_Boston             100 non-null    bool
#  4   city_Chicago            100 non-null    bool
#  5   city_Denver             100 non-null    bool
#  6   city_Houston            100 non-null    bool
#  7   city_Miami              100 non-null    bool
#  8   city_New York           100 non-null    bool
#  9   city_Phoenix            100 non-null    bool
#  10  city_Seattle            100 non-null    bool
#  11  department_Engineering  100 non-null    bool
#  12  department_Finance      100 non-null    bool
#  13  department_HR           100 non-null    bool
#  14  department_IT           100 non-null    bool
# ...

# %%
# # Reload the raw column, or fix it directly:
# df["salary"] = pd.to_numeric(df["salary"], errors="coerce")  # turns bad text into NaN
# df["salary"] = df["salary"].fillna(df["salary"].mean())      # now correctly fills with the number

df.to_csv("Clean_salaryData", index=False)

# %%
df.isnull().sum()
# df["salary"] = df["salary"].fillna(df["salary"].mean())
# Out:
# age                       0
# salary                    0
# city_Austin               0
# city_Boston               0
# city_Chicago              0
# city_Denver               0
# city_Houston              0
# city_Miami                0
# city_New York             0
# city_Phoenix              0
# city_Seattle              0
# department_Engineering    0
# department_Finance        0
# department_HR             0
# department_IT             0
# department_Marketing      0
# department_Operations     0
# department_Sales          0
# department_Support        0
# dtype: int64
