# %%
import pandas as pd 

df = pd.read_json("/home/thinkpad/Documents/BrototypeStudying/Paper two/week 8/code/data/data.json")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   name        100 non-null    str
#  2   age         91 non-null     float64
#  3   salary      87 non-null     float64
#  4   email       89 non-null     str
#  5   phone       88 non-null     str
#  6   city        89 non-null     str
#  7   department  85 non-null     str
#  8   join_date   88 non-null     str
# dtypes: float64(2), int64(1), str(6)
# memory usage: 7.2 KB

# %%
df.describe().round(2)
# Out:
#            id    age     salary
# count  100.00  91.00      87.00
# mean    50.50  42.23   86568.11
# std     29.01  13.58   34301.81
# min      1.00  20.00   30202.95
# 25%     25.75  27.50   58174.22
# 50%     50.50  45.00   81623.92
# 75%     75.25  54.00  114289.80
# max    100.00  65.00  147629.36

# %%
# import matplotlib.pyplot as plt

# df.boxplot(column="salary")
# plt.show()

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# age            9
# salary        13
# email         11
# phone         12
# city          11
# department    15
# join_date     12
# dtype: int64

# %%
df_model = df.dropna(subset= ["salary"])

x = df_model[["age", "city", "department","join_date"]]
y = df_model["salary"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("x_train",x_train.shape)
print("x_train",x_test.shape)
print("x_train",y_train.shape)
print("x_train",y_test.shape)
# Out:
# x_train (69, 4)
# x_train (18, 4)
# x_train (69,)
# x_train (18,)

# %%
x_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 69 entries, 62 to 58
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         61 non-null     float64
#  1   city        61 non-null     str
#  2   department  57 non-null     str
#  3   join_date   61 non-null     str
# dtypes: float64(1), str(3)
# memory usage: 2.7 KB

# %%
x_train.isnull().sum()
# Out:
# age            8
# city           8
# department    12
# join_date      8
# dtype: int64

# %%
import matplotlib.pyplot as plt

x_train.boxplot()
plt.show()

# %%
x_train.describe()
# Out:
#              age
# count  61.000000
# mean   44.278689
# std    13.290512
# min    20.000000
# 25%    35.000000
# 50%    46.000000
# 75%    56.000000
# max    63.000000

# %%
x_train["age"] = x_train["age"].fillna(x_train["age"].mean())
x_test["age"] = x_test["age"].fillna(x_train["age"].mean())

# %%
x_train["city"] = x_train["city"].fillna(x_train["city"].mode()[0])
x_train["department"] = x_train["department"].fillna(x_train["department"].mode()[0])
x_train["join_date"] = x_train["join_date"].fillna(x_train["join_date"].mode()[0])

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
print(x_train.to_string(index=False))
# Out:
#       age     city  department  join_date
# 37.000000   Denver Engineering 2022-06-11
# 52.000000   Austin          HR 2015-02-10
# 47.000000    Miami          IT 2016-04-08
# 55.000000    Miami     Support 2022-10-27
# 41.000000  Seattle     Finance 2024-12-09
# 41.000000 New York       Sales 2018-08-20
# 60.000000 New York     Support 2022-01-04
# 27.000000   Boston   Marketing 2021-11-04
# 23.000000  Seattle          HR 2022-07-21
